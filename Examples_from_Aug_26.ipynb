# %% [markdown]
# <a href="https://colab.research.google.com/github/derek-chan21/the-cutoff/blob/main/Examples_from_Aug_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(4+5)
print(3+1)
# Out:
# 9
# 4

# %%
x = 6
y = 8
z = x + y

# %%
print(x)
print(y)
print (z)
# Out:
# 6
# 8
# 14

# %%
myName = "Derek"
MyNumber = "6"
print("Your name is " + myName + "!") # Concentration
# Out:
# Your name is Derek!

# %%
myWage = 12.6 #Float
print("Your hourly wage is " + str(myWage))
# Out:
# Your hourly wage is 12.6

# %%
strMyWage = str(myWage)
